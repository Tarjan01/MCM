# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

data=pd.read_csv('swing_analysis.csv')

df = pd.DataFrame(data)

# Replace 0 values with NaN using numpy
df.replace(0, np.nan, inplace=True)

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Use seaborn to generate a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.show()

# %%
print(swing)
# Out:
# 0       1.328326
# 1      -0.674992
# 2       1.882127
# 3       0.566591
# 4      -0.359706
#           ...
# 7279    0.403945
# 7280    1.425579
# 7281    1.511653
# 7282   -0.244444
# 7283         NaN
# Name: swing, Length: 7284, dtype: float64

# %%
data2=pd.read_csv('swing_analysis.csv')
swing=data2['swing']
flow=data2['flow']
unf_err=data2['unf_err']
double_fault=data2['double_fault']
winner=data2['winner']
print(pearsonr(swing,flow))
print(pearsonr(swing,unf_err))
print(pearsonr(swing,double_fault))
print(pearsonr(swing,winner))
# Out:
# PearsonRResult(statistic=-0.0038465313674501626, pvalue=0.7432649014296521)
# PearsonRResult(statistic=-0.25453750526131064, pvalue=1.2511722964777797e-107)
# PearsonRResult(statistic=-0.10735360042900075, pvalue=4.8345008441008716e-20)
# PearsonRResult(statistic=0.12060544137904411, pvalue=6.53924381559957e-25)
